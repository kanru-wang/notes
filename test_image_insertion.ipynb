# %% [markdown]
# # Test image insertion 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>
# <br>
#
# # Test image insertion 2

# %%
# markdown code
# <img src="image/test_image_insertion/1.jpg">

# %% [markdown]
# <img src="image/test_image_insertion/1.jpg">

# %%
# <img src="subdirectory/MyImage.png" width=60 height=60 />

# %% [markdown]
# <img src="image/test_image_insertion/1.jpg" width=60 height=60>

# %% [markdown]
# <br>
# <br>
#
# # Test image insertion 3

# %%
from IPython.display import Image
Image(filename="image/test_image_insertion/2.jpg")

# %%
Image(filename="image/test_image_insertion/2.jpg", width=100, height=100)

# %% [markdown]
# <br>
# <br>
#
# ### If the image it wider than the display settings, use unconfined=True to disable max-width confinement of the image

# %%
from IPython.core.display import Image, display
display(Image(filename="image/test_image_insertion/2.jpg", width=1200, unconfined=True))

# %% [markdown]
# <br>
# <br>
#
# # Test image insertion 4

# %%
# markdown code
# ![](image/test_image_insertion/3.jpg)

# %% [markdown]
# ![](image/test_image_insertion/3.jpg)
